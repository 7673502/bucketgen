# %% [markdown]
# # BucketGen Demonstration
# This notebook serves as a demonstration on how to use BucketGen.
#
# **Note that this notebook requires having the [CIFAR-10](https://www.kaggle.com/datasets/swaroopkml/cifar10-pngs-in-folders) and [MNIST](https://www.kaggle.com/datasets/alexanderyyy/mnist-png) digits PNG dataset from Kaggle.**

# %%
import bucketgen as bg
import matplotlib.pyplot as plt

# %% [markdown]
# ## A Quick Example

# %%
dl = bg.DataLoader('mnist_png/train/0')
dl.images.shape
# Out:
# Successfully loaded 5923 / 5923 images.
# (5923, 28, 28, 1)

# %%
generator = bg.Generator(dl.images)

# %%
sample = generator.sample(show_result=True)

# %% [markdown]
# ## MNIST

# %%
dls = {}

for i in range(10):
    print(f'{i}: ', end='')
    dls[i] = bg.DataLoader(f'mnist_png/train/{i}')
# Out:
# 0: Successfully loaded 5923 / 5923 images.
# 1: Successfully loaded 6742 / 6742 images.
# 2: Successfully loaded 5958 / 5958 images.
# 3: Successfully loaded 6131 / 6131 images.
# 4: Successfully loaded 5842 / 5842 images.
# 5: Successfully loaded 5421 / 5421 images.
# 6: Successfully loaded 5918 / 5918 images.
# 7: Successfully loaded 6265 / 6265 images.
# 8: Successfully loaded 5851 / 5851 images.
# 9: Successfully loaded 5949 / 5949 images.

# %%
generators = {}

for i in range(10):
    print(f"now building {i} class generator")
    generators[i] = bg.Generator(dls[i].images)
# Out:
# now building 0 class generator
# now building 1 class generator
# now building 2 class generator
# now building 3 class generator
# now building 4 class generator
# now building 5 class generator
# now building 6 class generator
# now building 7 class generator
# now building 8 class generator
# now building 9 class generator

# %%
classes = ['zero', 'one', 'two', 'three', 'four', 'five', 'six', 'seven', 'eight', 'nine']

plt.figure(figsize=(10, 4.5))

for idx, i in enumerate(classes):
    sample = generators[idx].sample()
    ax = plt.subplot(2, 5, idx + 1)
    ax.imshow(sample, cmap='gray')
    ax.axis('off') 
    ax.set_title(i)
    
plt.subplots_adjust(left=0, right=1, top=1, bottom=0)
plt.show()

# %% [markdown]
# ## CIFAR-10
# The generator, as expected, does not produce an interpretable result when using the CIFAR-10 dataset.

# %%
classes = ['airplane', 'automobile', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck']

dls = {}

for i in classes:
    print(f'{i}: ', end='')
    dls[i] = bg.DataLoader(f'cifar10/train/{i}')
# Out:
# airplane: Successfully loaded 5000 / 5000 images.
# automobile: Successfully loaded 5000 / 5000 images.
# bird: Successfully loaded 5000 / 5000 images.
# cat: Successfully loaded 5000 / 5000 images.
# deer: Successfully loaded 5000 / 5000 images.
# dog: Successfully loaded 5000 / 5000 images.
# frog: Successfully loaded 5000 / 5000 images.
# horse: Successfully loaded 5000 / 5000 images.
# ship: Successfully loaded 5000 / 5000 images.
# truck: Successfully loaded 5000 / 5000 images.

# %%
generators = {}

for i in classes:
    print(f"now building {i} class generator")
    generators[i] = bg.Generator(dls[i].images)
# Out:
# now building airplane class generator
# now building automobile class generator
# now building bird class generator
# now building cat class generator
# now building deer class generator
# now building dog class generator
# now building frog class generator
# now building horse class generator
# now building ship class generator
# now building truck class generator

# %%
plt.figure(figsize=(10, 4.5))

for idx, i in enumerate(classes):
    sample = generators[i].sample()
    ax = plt.subplot(2, 5, idx + 1)
    ax.imshow(sample)
    ax.axis('off') 
    ax.set_title(i) 
    
plt.subplots_adjust(left=0, right=1, top=1, bottom=0)
plt.show()

# %% [markdown]
# ## CIFAR-10 Grayscale

# %%
classes = ['airplane', 'automobile', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck']

dls = {}

for i in classes:
    print(f'{i}: ', end='')
    dls[i] = bg.DataLoader(f'cifar10/train/{i}')
# Out:
# airplane: Successfully loaded 5000 / 5000 images.
# automobile: Successfully loaded 5000 / 5000 images.
# bird: Successfully loaded 5000 / 5000 images.
# cat: Successfully loaded 5000 / 5000 images.
# deer: Successfully loaded 5000 / 5000 images.
# dog: Successfully loaded 5000 / 5000 images.
# frog: Successfully loaded 5000 / 5000 images.
# horse: Successfully loaded 5000 / 5000 images.
# ship: Successfully loaded 5000 / 5000 images.
# truck: Successfully loaded 5000 / 5000 images.

# %%
generators = {}

for i in classes:
    print(f"now building {i} class generator")
    generators[i] = bg.Generator(dls[i].to_grayscale())
# Out:
# now building airplane class generator
# now building automobile class generator
# now building bird class generator
# now building cat class generator
# now building deer class generator
# now building dog class generator
# now building frog class generator
# now building horse class generator
# now building ship class generator
# now building truck class generator

# %%
plt.figure(figsize=(10, 4.5))

for idx, i in enumerate(classes):
    sample = generators[i].sample()
    ax = plt.subplot(2, 5, idx + 1)
    ax.imshow(sample, cmap='gray')
    ax.axis('off') 
    ax.set_title(i) 
    
plt.subplots_adjust(left=0, right=1, top=1, bottom=0)
plt.show()
